# %% [markdown]
# # <b>태양광 발전량 관계 데이터 시각화</b>

# %% [markdown]
# KEPCO Digital BootCamp A반 6조 Sprint 1 : 데이터 시각화 프로젝트
# <br>
#
# **개요**<br>
#
# (flowchart) 대체 예정  태양광 발전량, 전력시세, 발전소, 기상정보, 데이터 시각화 >
# <br>
#
# **도메인(Domain) 정보**<br>
#
# 1. 평균 기온
# 2. 일조율
# 3. 합계 일사량
# 4.

# %% [markdown]
# - <span style='color:red'><b>라이브러리(모듈) 호출</b></span>

# %%
import json, folium
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings('ignore',category=RuntimeWarning)
pd.set_option('mode.chained_assignment',  None)         # 경고 미출력
plt.rcParams['font.family'] = 'Malgun Gothic'  
plt.rcParams['font.size'] = 15
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# - <span style='color:red'><b>총 발전량 중 신재생 에너지 발전량 차지 비중</b></span>

# %%
# 2021년

portion = pd.read_csv('data1/전체 발전량 중 신재생 에너지 비중.csv',encoding='cp949')
portion = portion.iloc[-1,2:]
portion
portion['총발전량'] -= portion['신재생']
# 총발전량 + 신재생 이 전체 pie이므로 총발전량을 초과, 따라서 -(신재생)
portion.name=''
portion.plot.pie(figsize=(11,6),colors=['red','skyblue'],
                 labels=['신재생 에너지 발전량','신재생 제외 총 발전량'],
                 autopct='%1.2f%%')
plt.title('2021년 총발전량 중 신재생 에너지 발전량 비중')
plt.show()

# %% [markdown]
# - <span style='color:red'><b>년도별 총 발전량 중 신재생 에너지 발전량 차지 비중</b></span>

# %%
df = pd.read_csv('data/전체 발전량 중 신재생 에너지 비중.csv',encoding='cp949',index_col=0)
df.index = ['2018','2019','2020','2021']
df = df[['신재생','총발전량']]
fig, ax1 = plt.subplots(figsize=(10,6))
color_1 = 'tab:blue'
ax1.set_title('전체 발전량 중 신재생 에너지 비중', fontsize=13)
ax1.set_xlabel('년도')
ax1.set_ylabel('신재생 에너지', fontsize=14, color=color_1)
ax1.plot(df.index, df.신재생, marker='o', color=color_1,linewidth=3)
ax1.tick_params(axis='y', labelcolor=color_1)

ax2 = ax1.twinx()
color_2 = 'tab:red'
ax2.set_ylabel('총 발전량', fontsize=14, color=color_2)
ax2.plot(df.index, df.총발전량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

fig.tight_layout()
plt.show()

# %% [markdown]
# - <span style='color:red'><b>신재생에너지 중 총 발전량 비중

# %%
data = pd.read_csv('data3/태양광비중.csv',encoding='cp949')
data=data.rename(columns={'Unnamed: 0':'기준'})
data=data.dropna()
data=data.drop(2)
data=data.set_index('기준')
data=data.rename(index={'총발전량(GWh)':'신재생','신·재생에너지?발전량(GWh)':'태양광'})
data.loc['신재생'] = data.loc['신재생'].str.replace(',','')
data.loc['태양광'] = data.loc['태양광'].str.replace(',','')
data.loc['신재생'].astype(int)
data.loc['태양광'].astype(int)
data=data.astype(int)
df=data.T
df['신재생']=df['신재생'].astype(int)
df['태양광']=df['태양광'].astype(int)
df=df[['태양광','신재생']]
df.plot(kind='bar',stacked=True)
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# - <span style='color:red'><b>지역별 태양광 발전량</b></span>

# %%
# 발전량 : 데이터 전처리
plant = pd.read_csv('data1/태양에너지태양광_20230330105731.csv',encoding='cp949')
plant = plant[(plant['신재생에너지현황별(1)']=='발전량 (MWh)') | (plant['신재생에너지현황별(1)']=='신재생에너지현황별(1)')]   # 파일 가져오기 (plant 변수에 저장)
plant.drop(columns=['신재생에너지현황별(1)','신재생에너지현황별(2)'],inplace=True)
plant_loc = pd.read_excel('data1\태양광_발전소설치현황_2022.xls')['구분']
plant_loc
comlist = []
cnt = 0
for i in range(4):
    comlist.append(plant.iloc[:,cnt:cnt+18].T)
    cnt += 18
for i in range(4):
    comlist[i].drop(comlist[i].index[0],inplace=True)
    comlist[i].columns = ['지역','발전량']
for i in range(4):
    comlist[i].reset_index(inplace=True,drop=True)
new_df = pd.concat([comlist[0].지역,comlist[0].발전량,comlist[1].발전량,comlist[2].발전량,comlist[3].발전량],axis=1)
new_df['누적합'] = new_df.iloc[:,1:].sum(axis=1)
plant_loc = plant_loc.sort_values()
new_df.sort_values(by='지역',inplace=True)
new_df['지역'] = plant_loc.values
new_df.drop(columns = new_df.iloc[:,1:-2].columns,inplace=True)
new_dic = new_df.to_dict(orient='records')

# %%
# 발전량 : 데이터 지도 시각화
jsonfile = open('data1/Sido.json','r',encoding='utf8').read()     # 시도구분된 지역 json 파일 가져오기
jsondata = json.loads(jsonfile)                             
jsondata_loc = {'type': 'FeatureCollection'}                # Sido.json을 복사해서 일부 특성(키와 값) 추가
jsondata_pick = []
for idx in jsondata['features']:
    idx['id'] = idx['properties']['CTP_KOR_NM']             # Sido.
    for i in new_dic:
        if i['지역'] == idx['properties']['CTP_KOR_NM']:    # Sido.json의 지역과 일치하면 pop이라는 키 새로 만들고
            idx['properties']['pop'] = str(round(i['누적합']/(10**22),3)) + ' (10^22 MWh)'            # 해당 지역의 개수값을 넣기
    jsondata_pick.append(idx)                               # 추가된 값을 jsondata_pick에 저장
jsondata_loc['features'] = jsondata_pick                    # jsondata_loc의 features 키에 저장
map = folium.Map(location=[35.230194, 129.074721],zoom_start=8) # 지도 생성, location : 시작위치, zoom_start : 시작 시 확대정도
cho = folium.Choropleth(geo_data=jsondata_loc,              # 색상단계도 생성, geo_data : 참고할 위치정보 데이터
                  data=new_df,                            # data : geo_data와 비교해 맞출 데이터
                  columns=['지역','누적합'],                  # columns : data에서 사용할 열
                  fill_color="OrRd",                        # fill_color : 색
                  key_on='feature.id').add_to(map)          # key_on : data와 맞출 geo_data의 데이터
cho.geojson.add_child(                                      # 속성 추가(?)
    folium.features.GeoJsonPopup(['CTP_KOR_NM','pop'],labels=False,style='font-weight : bold')
)   # popup 넣기, geo_data의 properties 키의 값들 중 선택 가능, labels : 열이름 유무, style : 서식
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_732e5ea56b9b3d61076533538cb2644f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             font-weight : bold
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_732e5ea56b9b3d61076533538cb2644f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_732e5ea56b9b3d61076533538cb2644f = L.map(
#                 &quot;map_732e5ea56b9b3d61076533538cb2644f&quot;,
#                 {
#                     center: [35.230194, 129.074721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0007546dcb6a9a0c3531f3efd2a16f7f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_732e5ea56b9b3d61076533538cb2644f);
#
#
#             var choropleth_de9ff19602519d2ed9edec54c1a138e4 = L.featureGroup(
#                 {}
#             ).addTo(map_732e5ea56b9b3d61076533538cb2644f);
#
#
#         function geo_json_493838c48f6c43619cafc9588d2361bc_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uacbd\uc0c1\ubd81\ub3c4&quot;: case &quot;\ucda9\uccad\ub0a8\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc804\ub77c\ub0a8\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc804\ub77c\ubd81\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e34a33&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_493838c48f6c43619cafc9588d2361bc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_493838c48f6c43619cafc9588d2361bc = L.geoJson(null, {
#                 onEachFeature: geo_json_493838c48f6c43619cafc9588d2361bc_onEachFeature,
#
#                 style: geo_json_493838c48f6c43619cafc9588d2361bc_styler,
#         });
#
#         function geo_json_493838c48f6c43619cafc9588d2361bc_add (data) {
#             geo_json_493838c48f6c43619cafc9588d2361bc
#                 .addData(data)
#                 .addTo(choropleth_de9ff19602519d2ed9edec54c1a138e4);
#         }
#             geo_json_493838c48f6c43619cafc9588d2361bc_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[128.54880989370014, 38.301950820518755], [128.5600921732829, 38.25735515107489], [128.59761716763322, 38.21480959198724], [128.60765942875406, 38.15215810015938], [128.64206854447866, 38.106588627599855], [128.66939445927846, 38.08634208760778], [128.69458333244307, 38.0453480455091], [128.73326744935343, 38.01787054352603], [128.79463671088126, 37.92801060958252], [128.8233689458956, 37.90753318801803], [128.83001997197184, 37.88458455426084], [128.8786226699225, 37.8294251483049], [128.9852771172376, 37.74045442473868], [129.01482411622038, 37.70600771921262], [129.05505018456222, 37.675224044111836], [129.04353313092116, 37.642745963305245], [129.05392180246835, 37.62123228307141], [129.11550878570839, 37.57855036235084], [129.12163400699842, 37.52066201439543], [129.18932196241568, 37.45204451034289], [129.19776432627512, 37.41521414735909], [129.2513233979134, 37.380088360708676], [129.2506772120506, 37.362368874276115], [129.28084694703435, 37.31347366301054], [129.35527819358379, 37.235059804121235], [129.3411918281742, 37.17718338225454], [129.3633972863588, 37.146000904866405], [129.32482985566594, 37.142286218870495], [129.271238269404, 37.1163805689057], [129.22537770639696, 37.073720111851664], [129.2253141304669, 37.04455999175614], [129.18540948720124, 37.04171908095918], [129.1850295662585, 37.04657953042605],

# %% [markdown]
# - <span style='color:red'><b>지역별 전력 판매량(수요량)<b></span>

# %%
# 지역별 전력판매량(수요량)데이터 전처리 시작
df = pd.read_csv('data2/전력_지역별용도별판매량_2021.csv', skiprows=[0], encoding='cp949') # 첫 행을 건너뛰고 추출하기 위해 skiprows를 사용
df.head()
# Out:
#   용도별(1) 용도별(2)          계        서울        부산        대구        인천       광주  \
# 0     합계     소계  533430811  47295807  21067833  15443949  24901194  8973447
# 1    가정용     소계   77558386  14656127   4974889   3461331   4586787  2215918
# 2    공공용     소계   25025912   3575378   1280159    866403    943788   568578
# 3   서비스업     소계  148181597  27499011   7507103   5562421   7572381  3272320
# 4   농림어업     소계   18496161     19189    110847     79759    166780    76903
#
#         대전        울산  ...         경기        강원        충북        충남        전북  \
# 0  9748621  33593123  ...  133445948  16808006  28402063  48801626  21486861
# 1  2102655   1638730  ...   20775255   2289719   2385627   3184715   2588903
# 2  1107741    505195  ...    5941474   1478686   1360538   1121942   1082470
# 3  4112045   3497844  ...   37299472   6398541   5365193   7230648   5146076
# 4    37039     90321  ...    2712094    783547    920412   2291760   1704721
#
#          전남        경북        경남       제주 개성
# 0  33486886  44258297  35734059  5687730  -
# 1   2578822   3709248   4826057   971492  -
# 2   1373405   1706260   1437292   333656  -
# 3   5739917   8788905   9042660  2626848  -
# 4   3461170   2135822   2369741  1445104  -
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   용도별(1)  32 non-null     object
#  1   용도별(2)  32 non-null     object
#  2   계       32 non-null     int64
#  3   서울      32 non-null     int64
#  4   부산      32 non-null     int64
#  5   대구      32 non-null     int64
#  6   인천      32 non-null     int64
#  7   광주      32 non-null     int64
#  8   대전      32 non-null     int64
#  9   울산      32 non-null     object
#  10  세종      32 non-null     object
#  11  경기      32 non-null     int64
#  12  강원      32 non-null     int64
#  13  충북      32 non-null     int64
#  14  충남      32 non-null     int64
#  15  전북      32 non-null     object
#  16  전남      32 non-null     object
#  17  경북      32 non-null     int64
#  18  경남      32 non-null     int64
#  19  제주      32 non-null     object
#  20  개성      32 non-null     object
# dtypes: int64(13), object(8)
# memory usage: 5.4+ KB

# %%
df.columns # column 이름을 확인
# Out:
# Index(['용도별(1)', '용도별(2)', '계', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종',
#        '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '개성'],
#       dtype='object')

# %%
# df_area에 df의 서울부터 제주까지의 자료만 입력

df_area = df[['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종',
       '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주']] 
df_area
# Out:
#           서울        부산        대구        인천       광주       대전        울산  \
# 0   47295807  21067833  15443949  24901194  8973447  9748621  33593123
# 1   14656127   4974889   3461331   4586787  2215918  2102655   1638730
# 2    3575378   1280159    866403    943788   568578  1107741    505195
# 3   27499011   7507103   5562421   7572381  3272320  4112045   3497844
# 4      19189    110847     79759    166780    76903    37039     90321
# 5       1902     19576     15128     87829     3490      877     15117
# 6    1544200   7175259   5458907  11543628  2836237  2388264  27845916
# 7     229770    588799    215988    647223   135456   141766    181879
# 8      15592     21263     22341     14937    41626    18495     15115
# 9         88         4        34        13    14127    64379         -
# 10    108992    261194    734602     38272   140867    30573    794738
# 11    310266     38375     39972     12711     1801     2399       911
# 12     21502    104194      4097      6929      154     2896       418
# 13      4201     45325     16502    513450     6316     4702     17620
# 14     37773     29569    459703     50909    50884   540988    580987
# 15    204727     26082     38962     86836    18402    14821      3633
# 16      3193      5515     13056    901502      624      618   6085161
# 17     42368    274846    190597    366478    69093   227197  11015276
# 18     16638     13010     15069    327460     2224    54673      4408
# 19     49867    193589    215194    276272   316139   374948    596678
# 20     24756     89499     76779    196273    22429    52177    175947
# 21     12425   2005157    280566   1985355    54321    48358   4100923
# 22     51333    786774    612020    624201   164353    57161    192940
# 23     62799    102955    259983   1307722   816994   298833     35984
# 24     43783     67875     90830   2021417    28650    47503     18490
# 25     19253    137952    297138    185469   233907    89024    570876
# 26    136043    985736    490896    893800   202561    94759    181995
# 27     16930   1129922   1286734    502177   500347   190949   2265967
# 28     19758    218617     48875     51922     6020     8038   1003006
# 29      3520     10187     15859    114586     5048     4032      1215
# 30    107280     36174     31556    414074     2155    18654       800
# 31      1343      2645      1555      3637     1739      322       950
#
#          세종         경기        강원        충북        충남        전북        전남  \
# 0   4295363  133445948  16808006  28402063  48801626  21486861  33486886
# 1    612111   20775255   2289719   2385627   3184715   2588903   2578822
# 2    342947    5941474   1478686   1360538   1121942   1082470   1373405
# 3   1520211   37299472   6398541   5365193   7230648   5146076   5739917
# 4     90952    2712094    783547    920412   2291760   1704721   3461170
# 5     11510     271724    452010    128817    341587     69757     82528
# 6   1717632   66445929   5405503  18241476  34630974  10894934  20251044
# 7    110529    2742042    506910   1211162   1341884   1671103    850474
# 8      9363     305586    116978    140690     84892    112874     22894
# 9         -       3204         5      5796        14         -         -
# 10    26896    1474890     13923    179526    171810    667959    168120
# 11      283     137027      1177      5749      9213     13568      4426
# 12     2243     175447       269     61387     15624      5780       605
# 13     1197     500613     23564     59294    130428    264414     24365
# 14   370162    1909845     24747    839135    778567   1072650     96801
# 15     3866     673633      3678     34065     48617      8464      1916
# 16      317      41939      1257     15947   4368299      3757   1782675
# 17   147510    5984298     92586   1786806   3907125   2048646  11517313
# 18    44001     956292    105609    717012    270490     34448     49401
# 19   127579    2308095     94009   1152168   1106867    250996    370081
# 20   396789    1792694   3049750   2294049    893663    616046    567606
# 21    39712    1980014    944326    391285   4722811   2318215   3384074
# 22    12525    2158925     34831    805879    564207    133950    136578
# 23   234153   33034901     58655   5191666  11086797    459813     55441
# 24     2681     597352     37216     87311    631219     27410     12480
# 25    70821    1115707     37035   1477416    917515    158572    460652
# 26    32801    3927790     30084    444625    766500    164708     68093
# 27    78725    2905822    173438    711643   2690227    796880     66655
# 28      136      80430     37589     15741     32899     39754    583010
# 29      469     442026      6872     29410      9274      4523      7495
# 30     4548    1181054      7982    578663     76101     15024      6263
# 31      327      16302      3012      5050      5933      5380     13625
#
#           경북        경남       제주
# 0   44258297  35734059  5687730
# 1    3709248   4826057   971492
# 2    1706260   1437292   333656
# 3    8788905   9042660  2626848
# 4    2135822   2369741  1445104
# 5     228781     68712     7547
# 6   27689281  17989597   303083
# 7     559796    873591   106057
# 8      77073    124395    84441
# 9      34051     71917        -
# 10   3145234    207626      487
# 11     10061      6138      146
# 12      6774     63853       16
# 13     82622     64471     1500
# 14    347648    794446    25088
# 15     13735     21711     1322
# 16     46461     11009       41
# 17   2775867    782246    28015
# 18     46964     10192     7876
# 19    939909   1094644     6423
# 20    993358    432310    26329
# 21   9051156   3722344     2639
# 22    806988   1618947     2683
# 23   4149463    630793     1523
# 24    186291    242550      787
# 25    980590    957698      871
# 26    821257   1887576     2263
# 27   2424074   2242292      292
# 28    134834   1822116      378
# 29     24383     22047     1252
# 30     25115    273972     1397
# 31      5577     10717     1259

# %%
df_drop = df_area.drop(df_area.index[1:32]) # 0번 index를 제외한 나머지를 drop 하여 지역별 합계 데이터만 추출
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   서울      1 non-null      int64
#  1   부산      1 non-null      int64
#  2   대구      1 non-null      int64
#  3   인천      1 non-null      int64
#  4   광주      1 non-null      int64
#  5   대전      1 non-null      int64
#  6   울산      1 non-null      object
#  7   세종      1 non-null      object
#  8   경기      1 non-null      int64
#  9   강원      1 non-null      int64
#  10  충북      1 non-null      int64
#  11  충남      1 non-null      int64
#  12  전북      1 non-null      object
#  13  전남      1 non-null      object
#  14  경북      1 non-null      int64
#  15  경남      1 non-null      int64
#  16  제주      1 non-null      object
# dtypes: int64(12), object(5)
# memory usage: 264.0+ bytes

# %%
# df_drop의 column 중 datatype이 object인 5곳을 지정하여 int64 형식으로 변경
df_astype = df_drop.astype({'울산':'int64', '세종':'int64', '전북':'int64', '전남':'int64' ,'제주':'int64'})
df_astype.columns
# Out:
# Index(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
#        '전북', '전남', '경북', '경남', '제주'],
#       dtype='object')

# %%
df_astype
# Out:
#          서울        부산        대구        인천       광주       대전        울산  \
# 0  47295807  21067833  15443949  24901194  8973447  9748621  33593123
#
#         세종         경기        강원        충북        충남        전북        전남  \
# 0  4295363  133445948  16808006  28402063  48801626  21486861  33486886
#
#          경북        경남       제주
# 0  44258297  35734059  5687730

# %%
# df_astype의 행과 열을 바꾸기 위해 transpose를 사용
df_trans = df_astype.T
df_reset = df_trans.reset_index() # Column 명을 reset
df_reset
# Out:
#    index          0
# 0     서울   47295807
# 1     부산   21067833
# 2     대구   15443949
# 3     인천   24901194
# 4     광주    8973447
# 5     대전    9748621
# 6     울산   33593123
# 7     세종    4295363
# 8     경기  133445948
# 9     강원   16808006
# 10    충북   28402063
# 11    충남   48801626
# 12    전북   21486861
# 13    전남   33486886
# 14    경북   44258297
# 15    경남   35734059
# 16    제주    5687730

# %%
df_reset.columns = ['지역','판매량'] # column 명을 각각 '지역'과 '판매량'으로 재정의
df_reset
# Out:
#     지역        판매량
# 0   서울   47295807
# 1   부산   21067833
# 2   대구   15443949
# 3   인천   24901194
# 4   광주    8973447
# 5   대전    9748621
# 6   울산   33593123
# 7   세종    4295363
# 8   경기  133445948
# 9   강원   16808006
# 10  충북   28402063
# 11  충남   48801626
# 12  전북   21486861
# 13  전남   33486886
# 14  경북   44258297
# 15  경남   35734059
# 16  제주    5687730

# %%
# df_reset의 '지역' 레코드를 바로 folium.choropleth 에 적용할 수 없기에 태양광_발전소설치현황_2022.xls의 '구분' column을 호출, local로 저장
local = pd.read_excel('data2/태양광_발전소설치현황_2022.xls')['구분'] 
local

sales = df_reset['판매량'] # df_reset의 '지역' 레코드 대신 local로 대체하고자 '판매량' column만 추출, sales로 저장
a = pd.DataFrame([local,sales]).T # local과 sales의 레코드로 구성된 DataFrame 생성하고 바로 행과 열을 바꿈
a.columns = ['지역','판매량'] # column 명을 각각 '지역'과 '판매량'으로 재정의
a_dic = a.to_dict(orient='records') # a에 저장된 DataFrame을 지역과 판매량으로 구분된 딕셔너리로 변환
a_dic
# Out:
# [{'지역': '서울특별시', '판매량': 47295807},
#  {'지역': '부산광역시', '판매량': 21067833},
#  {'지역': '대구광역시', '판매량': 15443949},
#  {'지역': '인천광역시', '판매량': 24901194},
#  {'지역': '광주광역시', '판매량': 8973447},
#  {'지역': '대전광역시', '판매량': 9748621},
#  {'지역': '울산광역시', '판매량': 33593123},
#  {'지역': '세종특별자치시', '판매량': 4295363},
#  {'지역': '경기도', '판매량': 133445948},
#  {'지역': '강원도', '판매량': 16808006},
#  {'지역': '충청북도', '판매량': 28402063},
#  {'지역': '충청남도', '판매량': 48801626},
#  {'지역': '전라북도', '판매량': 21486861},
#  {'지역': '전라남도', '판매량': 33486886},
#  {'지역': '경상북도', '판매량': 44258297},
#  {'지역': '경상남도', '판매량': 35734059},
#  {'지역': '제주특별자치도', '판매량': 5687730}]

# %%
# 지역별 전력판매량(수요량)데이터 지도로 시각화

# %%
jsonfile = open('data2/Sido.json','r',encoding='utf8').read()     # 시도구분된 지역 json 파일 가져오기
jsondata = json.loads(jsonfile)                             
jsondata_loc = {'type': 'FeatureCollection'}                # Sido.json을 복사해서 일부 특성(키와 값) 추가
jsondata_pick = []
for idx in jsondata['features']:
    idx['id'] = idx['properties']['CTP_KOR_NM']             # Sido.
    for i in a_dic:
        if i['지역'] == idx['properties']['CTP_KOR_NM']:    # Sido.json의 지역과 일치하면 pop이라는 키 새로 만들고
            idx['properties']['pop'] = i['판매량']          # 해당 지역의 판매량을 넣기
    jsondata_pick.append(idx)                               # 추가된 값을 jsondata_pick에 저장
jsondata_loc['features'] = jsondata_pick                    # jsondata_loc의 features 키에 저장
map = folium.Map(location=[35.230194, 129.074721],zoom_start=7) # 지도 생성, location : 시작위치, zoom_start : 시작 시 확대정도
cho = folium.Choropleth(geo_data=jsondata_loc,              # 색상단계도 생성, geo_data : 참고할 위치정보 데이터
                  data=a,                                   # data : geo_data와 비교해 맞출 데이터
                  columns=['지역','판매량'],                  # columns : data에서 사용할 열
                  fill_color="OrRd",                        # fill_color : 색
                  key_on='feature.id',                      # key_on : data와 맞출 geo_data의 데이터
                  legend_name='2021년 지역별 전력판매량').add_to(map)  # legend_name : 범례 제목 입력        
cho.geojson.add_child(                                      # 속성 부여
    folium.features.GeoJsonPopup(['CTP_KOR_NM','pop'],labels=False,style='font-weight : bold')
)   # popup 넣기, geo_data의 properties 키의 값들 중 선택 가능, labels : 열이름 유무, style : 서식
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6fdbd359386333fb8c320a407306539 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             font-weight : bold
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6fdbd359386333fb8c320a407306539&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6fdbd359386333fb8c320a407306539 = L.map(
#                 &quot;map_c6fdbd359386333fb8c320a407306539&quot;,
#                 {
#                     center: [35.230194, 129.074721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_164433d03f07e8833e5bf2bb98d62f96 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c6fdbd359386333fb8c320a407306539);
#
#
#             var choropleth_a14e345a2310dba27e650c096402b106 = L.featureGroup(
#                 {}
#             ).addTo(map_c6fdbd359386333fb8c320a407306539);
#
#
#         function geo_json_60658864c81c5b1b220c5093933508ae_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uacbd\uae30\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uacbd\uc0c1\ub0a8\ub3c4&quot;: case &quot;\uacbd\uc0c1\ubd81\ub3c4&quot;: case &quot;\uc11c\uc6b8\ud2b9\ubcc4\uc2dc&quot;: case &quot;\uc6b8\uc0b0\uad11\uc5ed\uc2dc&quot;: case &quot;\uc804\ub77c\ub0a8\ub3c4&quot;: case &quot;\ucda9\uccad\ubd81\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdd49e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ucda9\uccad\ub0a8\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdbb84&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_60658864c81c5b1b220c5093933508ae_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_60658864c81c5b1b220c5093933508ae = L.geoJson(null, {
#                 onEachFeature: geo_json_60658864c81c5b1b220c5093933508ae_onEachFeature,
#
#                 style: geo_json_60658864c81c5b1b220c5093933508ae_styler,
#         });
#
#         function geo_json_60658864c81c5b1b220c5093933508ae_add (data) {
#             geo_json_60658864c81c5b1b220c5093933508ae
#                 .addData(data)
#                 .addTo(choropleth_a14e345a2310dba27e650c096402b106);
#         }
#             geo_json_60658864c81c5b1b220c5093933508ae_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[128.54880989370014, 38.301950820518755], [128.5600921732829, 38.25735515107489], [128.59761716763322, 38.21480959198724], [128.60765942875406, 38.15215810015938], [128.64206854447866, 38.106588627599855], [128.66939445927846, 38.08634208760778], [128.69458333244307, 38.0453480455091], [128.73326744935343, 38.01787054352603], [128.79463671088126, 37.92801060958252], [128.8233689458956, 37.90753318801803], [128.83001997197184, 37.88458455426084], [128.8786226699225, 37.8294251483049], [128.9852771172376, 37.74045442473868], [129.01482411622038, 37.70600771921262], [129.05505018456222, 37.675224044111836], [129.04353313092116, 37.642745963305245], [129.05392180246835, 37.62123228307141], [129.11550878570839, 37.57855036235084], [129.12163400699842, 37.52066201439543], [129.18932196241568, 37.45204451034289], [129.19776432627512, 37.41521414735909], [129.2513233979134, 37.380088360708676], [129.2506772120506, 37.362368874276115], [129.28084694703435, 37.31347366301054], [129.35527819358379, 37.235059804121235], [129.3411918281742, 37.17718338225454], [129.3633972863588, 37.146000904866405], [129.32482985566594, 37.142286218870495], [129.271238269404, 37.1

# %% [markdown]
# - <span style='color:red'><b>지역별 발전소 설치수</b></span>

# %%
# 발전소 : 데이터 전처리
plant = pd.read_excel('data1/태양광_발전소설치현황_2022.xls')   # 파일 가져오기 (plant 변수에 저장)
plant_loc = plant['구분']                                 # 구분열을 따로 저장(지역)
plant.drop(columns=['구분','2022년 설치발전소 개소','누적 발전소 개소(2022년까지)'],inplace=True)
# 필요없는 열 삭제 : 2021년도 까지만 사용 - 2022~ 열 삭제, inplace로 plant 원본 변경
plant = plant.cumsum(1).iloc[:,-1]                        
# plant의 누적값을 계산하고, 끝의 열만을 가져와 다시 저장(덮어씀)
# cumsum(axis,...) : 누적값 계산, 안의 첫번째 값은 axis이고 1로 설정하면 열 방향(오른쪽)으로 누적값 계산
# iloc[index,column] : 특정 위치 값(열) 가져오기.
# inplace 옵션이 없어 plant에 다시 저장해서 업데이트
plant_df = pd.concat([plant_loc,plant],axis=1)            # 지역과 누적값(개수)열을 합쳐 DataFrame 생성
plant_df.columns = ['지역','개수']                        # 열의 이름을 새로 지정
plant_dic = plant_df.to_dict(orient='records')            # DataFrame을 지역 키와 개수 키로 나뉜 딕셔너리로 변환

# %%
# 발전소 : 데이터 지도 시각화
jsonfile = open('data1/Sido.json','r',encoding='utf8').read()     # 시도구분된 지역 json 파일 가져오기
jsondata = json.loads(jsonfile)                             
jsondata_loc = {'type': 'FeatureCollection'}                # Sido.json을 복사해서 일부 특성(키와 값) 추가
jsondata_pick = []
for idx in jsondata['features']:
    idx['id'] = idx['properties']['CTP_KOR_NM']             # Sido.
    for i in plant_dic:
        if i['지역'] == idx['properties']['CTP_KOR_NM']:    # Sido.json의 지역과 일치하면 pop이라는 키 새로 만들고
            idx['properties']['pop'] = str(i['개수']) + ' 개'            # 해당 지역의 개수값을 넣기
    jsondata_pick.append(idx)                               # 추가된 값을 jsondata_pick에 저장
jsondata_loc['features'] = jsondata_pick                    # jsondata_loc의 features 키에 저장
map = folium.Map(location=[35.230194, 129.074721],zoom_start=8) # 지도 생성, location : 시작위치, zoom_start : 시작 시 확대정도
cho = folium.Choropleth(geo_data=jsondata_loc,              # 색상단계도 생성, geo_data : 참고할 위치정보 데이터
                  data=plant_df,                            # data : geo_data와 비교해 맞출 데이터
                  columns=['지역','개수'],                  # columns : data에서 사용할 열
                  fill_color="OrRd",                        # fill_color : 색
                  key_on='feature.id').add_to(map)          # key_on : data와 맞출 geo_data의 데이터
cho.geojson.add_child(                                      # 속성 추가(?)
    folium.features.GeoJsonPopup(['CTP_KOR_NM','pop'],labels=False,style='font-weight : bold')
)   # popup 넣기, geo_data의 properties 키의 값들 중 선택 가능, labels : 열이름 유무, style : 서식
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3d624fc1742b765b8588b3dc4f23ff2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             font-weight : bold
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3d624fc1742b765b8588b3dc4f23ff2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3d624fc1742b765b8588b3dc4f23ff2 = L.map(
#                 &quot;map_a3d624fc1742b765b8588b3dc4f23ff2&quot;,
#                 {
#                     center: [35.230194, 129.074721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05b5acf6d452f47fd26449fcfcd955ad = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a3d624fc1742b765b8588b3dc4f23ff2);
#
#
#             var choropleth_529e132c13940e1a31871e2b81b425cb = L.featureGroup(
#                 {}
#             ).addTo(map_a3d624fc1742b765b8588b3dc4f23ff2);
#
#
#         function geo_json_9c8540580c07eb09d5612d2fc8279050_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\uc6d0\ub3c4&quot;: case &quot;\uacbd\uc0c1\ub0a8\ub3c4&quot;: case &quot;\ucda9\uccad\ubd81\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdd49e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uacbd\uae30\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdbb84&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uacbd\uc0c1\ubd81\ub3c4&quot;: case &quot;\uc804\ub77c\ub0a8\ub3c4&quot;: case &quot;\ucda9\uccad\ub0a8\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc804\ub77c\ubd81\ub3c4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_9c8540580c07eb09d5612d2fc8279050_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9c8540580c07eb09d5612d2fc8279050 = L.geoJson(null, {
#                 onEachFeature: geo_json_9c8540580c07eb09d5612d2fc8279050_onEachFeature,
#
#                 style: geo_json_9c8540580c07eb09d5612d2fc8279050_styler,
#         });
#
#         function geo_json_9c8540580c07eb09d5612d2fc8279050_add (data) {
#             geo_json_9c8540580c07eb09d5612d2fc8279050
#                 .addData(data)
#                 .addTo(choropleth_529e132c13940e1a31871e2b81b425cb);
#         }
#             geo_json_9c8540580c07eb09d5612d2fc8279050_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[128.54880989370014, 38.301950820518755], [128.5600921732829, 38.25735515107489], [128.59761716763322, 38.21480959198724], [128.60765942875406, 38.15215810015938], [128.64206854447866, 38.106588627599855], [128.66939445927846, 38.08634208760778], [128.69458333244307, 38.0453480455091], [128.73326744935343, 38.01787054352603], [128.79463671088126, 37.92801060958252], [128.8233689458956, 37.90753318801803], [128.83001997197184, 37.88458455426084], [128.8786226699225, 37.8294251483049], [128.9852771172376, 37.74045442473868], [129.01482411622038, 37.70600771921262], [129.05505018456222, 37.675224044111836], [129.04353313092116, 37.642745963305245], [129.05392180246835, 37.62123228307141], [129.11550878570839, 37.57855036235084], [129.12163400699842, 37.52066201439543], [129.18932196241568, 37.45204451034289], [129.19776432627512, 37.41521414735909], [129.2513233979134, 37.380088360708676], [129.2506772120506, 37.362368874276115], [129.28084694703435, 37.31347366301054], [

# %% [markdown]
# - <span style='color:red'><b>태양광발전설비(발전소) 수 대비 태양광발전량</b></span>

# %%
df = pd.read_csv('data/태양광_발전량.csv',encoding = 'cp949',index_col=0) #index_col=0 하지않으면 unnamed:0 가 뜸
df = df.sort_values(by='지역')
df
# Out:
#     지역         누적발전량
# 9   강원  6.421820e+25
# 8   경기  5.961419e+25
# 15  경남  6.852480e+25
# 14  경북  1.131678e+27
# 4   광주  1.678562e+23
# 2   대구  9.165012e+22
# 5   대전  5.254363e+20
# 1   부산  1.317482e+23
# 0   서울  1.296342e+23
# 7   세종  5.458362e+19
# 6   울산  5.800673e+21
# 3   인천  1.090251e+23
# 13  전남  1.985162e+27
# 12  전북  1.560590e+27
# 16  제주  2.064803e+23
# 11  충남  1.112940e+27
# 10  충북  4.926337e+25

# %%
facil = pd.read_excel('data/태양광_발전소설치현황_2022.xls')
facil = facil.drop(columns=['2022년 설치발전소 개소','누적 발전소 개소(2022년까지)'])
facil
# Out:
#          구분  2019년까지 설치발전소 개소  2020년 설치발전소 개소  2021년 설치발전소 개소
# 0     서울특별시               372              53              59
# 1     부산광역시               311             102              92
# 2     대구광역시               379             156             204
# 3     인천광역시               440             117              60
# 4     광주광역시               884             197             220
# 5     대전광역시               264              76              85
# 6     울산광역시               181              94              88
# 7   세종특별자치시               221              55              56
# 8       경기도              4607            1718            1780
# 9       강원도              3593            1561            1639
# 10     충청북도              3658            2028            1844
# 11     충청남도              6364            3491            3992
# 12     전라북도             12504            5851            5165
# 13     전라남도              8214            3757            3279
# 14     경상북도              5577            3042            4961
# 15     경상남도              3549            1554            1699
# 16  제주특별자치도               833             302             360

# %%
local = facil['구분']
facil = facil.drop(columns=['구분']).cumsum(1)
facil = facil['2021년 설치발전소 개소']
facil.name = '2021년까지 누적값'
sulby = pd.DataFrame([local,facil.values])
sulby.columns = sulby.loc['구분'].apply(lambda x : x[:2] if len(x) != 4 else x[0]+x[2])
sulby = sulby.T.drop(columns='구분').reset_index(False)
sulby.rename(columns={'구분':'지역','Unnamed 0':'발전소개수'},inplace=True)
sulby.head()
# Out:
#    지역 발전소개수
# 0  서울   484
# 1  부산   505
# 2  대구   739
# 3  인천   617
# 4  광주  1301

# %%
sulby = sulby.sort_values(by=['지역'])
sulby
# Out:
#     지역  발전소개수
# 9   강원   6793
# 8   경기   8105
# 15  경남   6802
# 14  경북  13580
# 4   광주   1301
# 2   대구    739
# 5   대전    425
# 1   부산    505
# 0   서울    484
# 7   세종    332
# 6   울산    363
# 3   인천    617
# 13  전남  15250
# 12  전북  23520
# 16  제주   1495
# 11  충남  13847
# 10  충북   7530

# %%
result = pd.merge(df, sulby)
result
result.columns=['지역','발전량','발전소개수']
result
# Out:
#     지역           발전량  발전소개수
# 0   강원  6.421820e+25   6793
# 1   경기  5.961419e+25   8105
# 2   경남  6.852480e+25   6802
# 3   경북  1.131678e+27  13580
# 4   광주  1.678562e+23   1301
# 5   대구  9.165012e+22    739
# 6   대전  5.254363e+20    425
# 7   부산  1.317482e+23    505
# 8   서울  1.296342e+23    484
# 9   세종  5.458362e+19    332
# 10  울산  5.800673e+21    363
# 11  인천  1.090251e+23    617
# 12  전남  1.985162e+27  15250
# 13  전북  1.560590e+27  23520
# 14  제주  2.064803e+23   1495
# 15  충남  1.112940e+27  13847
# 16  충북  4.926337e+25   7530

# %%
plt.figure(figsize=(20,5)) 
plt.subplot(1,2,1)
plt.bar(result['지역'],result['발전소개수'],color='pink')
plt.plot(result['지역'],result['발전소개수'],marker='o',color='r',markersize=10)
plt.title('지역별 태양광 발전소개수',fontsize=15)
plt.xlabel('지역')
plt.ylabel('발전소개수')
plt.subplot(1,2,2)
plt.bar(result['지역'],result['발전량'],color='skyblue')
plt.plot(result['지역'],result['발전량'],marker='o',markersize=10)
plt.xlabel('지역')
plt.ylabel('발전량')
plt.title('지역별 태양광 발전량', fontsize = 15)
plt.show()

# %%
d = result.set_index('지역')
d = d.sort_values(by='발전소개수')

# %%
#스케일이 다른 2개 그리기, 스케일이 작은 값의 시각화가 의미가 없기 때문
fig, ax1 = plt.subplots(figsize=(10,6))
color_1 = 'tab:blue'
ax1.set_title('태양광 발전소 대비 발전량', fontsize=13)
ax1.set_xlabel('년도')
ax1.set_ylabel('태양광 발전량', fontsize=14, color=color_1)
ax1.plot(d.index, d.발전량, marker='o', color=color_1,linewidth=3)
ax1.tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1.twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('발전소개수', fontsize=14, color=color_2)
ax2.plot(d.index, d.발전소개수, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

fig.tight_layout()
plt.show()

# %% [markdown]
# - <span style='color:red'><b>지역별 인구밀도</b></span>

# %%
# 지역별 인구밀도 데이터 전처리 시작

# %%
df = pd.read_csv('data2/인구밀도_인구주택총조사기준_2018-2021.csv', encoding='cp949')
df
# Out:
#       행정구역별     2018     2019     2020     2021
# 0        전국    514.4    515.7    516.2    515.2
# 1     서울특별시  15983.7  15926.9  15839.0  15650.1
# 2     부산광역시   4409.8   4379.7   4348.9   4316.4
# 3     대구광역시   2766.7   2750.3   2728.6   2702.2
# 4     인천광역시   2761.4   2776.6   2765.1   2772.8
# 5     광주광역시   2973.2   2972.7   2948.5   2944.0
# 6     대전광역시   2801.0   2777.5   2758.1   2742.8
# 7     울산광역시   1083.4   1076.9   1069.0   1055.0
# 8   세종특별자치시    671.9    727.3    761.3    787.7
# 9       경기도   1286.2   1305.0   1325.3   1338.9
# 10      강원도     90.3     90.3     90.4     90.4
# 11     충청북도    218.8    220.0    220.3    219.4
# 12     충청남도    265.1    265.4    264.0    263.8
# 13     전라북도    225.3    224.0    223.4    221.4
# 14     전라남도    145.0    144.8    144.9    143.9
# 15     경상북도    140.4    140.2    138.9    138.4
# 16     경상남도    317.9    317.6    316.2    313.6
# 17      제주도    355.8    359.4    362.6    363.8

# %%
df_drop = df.iloc[1:18] # 전국에 해당하는 레코드는 쓰이지 않으므로 서울특별시부터 제주도까지만 iloc method를 통해 추출

# %%
df_drop
df_drop.columns
# Out:
# Index(['행정구역별', '2018', '2019', '2020', '2021'], dtype='object')

# %%
df_2021 = df_drop[['행정구역별', '2021']] # 2021년 기준의 지역별 인구밀도만 필요하므로 해당 column만 추출
df_2021.columns = ['지역','인구밀도']

# %%
df_s = df_2021
df_s = df_s.reset_index(drop=True) # reset_index method 중 drop의 경우에는 기본값이 False. column에 index를 삽입하지 않으려 True값 입력

# %%
local = pd.read_excel('data2/태양광_발전소설치현황_2022.xls')['구분'] # 지역명이 필요하여 태양광_발전소설치현황_2022.csv 를 불러옴
local
# Out:
# 0       서울특별시
# 1       부산광역시
# 2       대구광역시
# 3       인천광역시
# 4       광주광역시
# 5       대전광역시
# 6       울산광역시
# 7     세종특별자치시
# 8         경기도
# 9         강원도
# 10       충청북도
# 11       충청남도
# 12       전라북도
# 13       전라남도
# 14       경상북도
# 15       경상남도
# 16    제주특별자치도
# Name: 구분, dtype: object

# %%
people = df_s['인구밀도'] # 인구밀도 column만을 people 변수로 불러옴
a = pd.DataFrame([local,people]).T # a에 local과 people 변수로 구성된 DataFrame을 구성

a.columns = ['지역','인구밀도'] # column명을 지역, 인구밀도로 변경
a
# Out:
#          지역     인구밀도
# 0     서울특별시  15650.1
# 1     부산광역시   4316.4
# 2     대구광역시   2702.2
# 3     인천광역시   2772.8
# 4     광주광역시   2944.0
# 5     대전광역시   2742.8
# 6     울산광역시   1055.0
# 7   세종특별자치시    787.7
# 8       경기도   1338.9
# 9       강원도     90.4
# 10     충청북도    219.4
# 11     충청남도    263.8
# 12     전라북도    221.4
# 13     전라남도    143.9
# 14     경상북도    138.4
# 15     경상남도    313.6
# 16  제주특별자치도    363.8

# %%
a_dic = a.to_dict(orient='records')  # 위 DataFrame을 지역 키와 개수 키로 나뉜 딕셔너리로 변환
a_dic
# Out:
# [{'지역': '서울특별시', '인구밀도': 15650.1},
#  {'지역': '부산광역시', '인구밀도': 4316.4},
#  {'지역': '대구광역시', '인구밀도': 2702.2},
#  {'지역': '인천광역시', '인구밀도': 2772.8},
#  {'지역': '광주광역시', '인구밀도': 2944.0},
#  {'지역': '대전광역시', '인구밀도': 2742.8},
#  {'지역': '울산광역시', '인구밀도': 1055.0},
#  {'지역': '세종특별자치시', '인구밀도': 787.7},
#  {'지역': '경기도', '인구밀도': 1338.9},
#  {'지역': '강원도', '인구밀도': 90.4},
#  {'지역': '충청북도', '인구밀도': 219.4},
#  {'지역': '충청남도', '인구밀도': 263.8},
#  {'지역': '전라북도', '인구밀도': 221.4},
#  {'지역': '전라남도', '인구밀도': 143.9},
#  {'지역': '경상북도', '인구밀도': 138.4},
#  {'지역': '경상남도', '인구밀도': 313.6},
#  {'지역': '제주특별자치도', '인구밀도': 363.8}]

# %%
# 지역별 인구밀도 데이터 지도 시각화

# %%
jsonfile = open('data2/Sido.json','r',encoding='utf8').read()     # 시도구분된 지역 json 파일 가져오기
jsondata = json.loads(jsonfile)                             
jsondata_loc = {'type': 'FeatureCollection'}                # Sido.json을 복사해서 일부 특성(키와 값) 추가
jsondata_pick = []
for idx in jsondata['features']:
    idx['id'] = idx['properties']['CTP_KOR_NM']             # Sido.
    for i in a_dic:
        if i['지역'] == idx['properties']['CTP_KOR_NM']:    # Sido.json의 지역과 일치하면 pop이라는 키 새로 만들고
            idx['properties']['pop'] = i['인구밀도']        # 해당 지역의 인구밀도를 입력
    jsondata_pick.append(idx)                               # 추가된 값을 jsondata_pick에 저장
jsondata_loc['features'] = jsondata_pick                    # jsondata_loc의 features 키에 저장
map = folium.Map(location=[35.230194, 129.074721],zoom_start=7) # 지도 생성, location : 시작위치, zoom_start : 시작 시 확대정도
cho = folium.Choropleth(geo_data=jsondata_loc,              # 색상단계도 생성, geo_data : 참고할 위치정보 데이터
                  data=a,                                   # data : geo_data와 비교해 맞출 데이터
                  columns=['지역', '인구밀도'],             # columns : data에서 사용할 열
                  fill_color="OrRd",                        # fill_color : 색 
                  key_on='feature.id',                      # key_on : data와 맞출 geo_data의 데이터
                  legend_name='2021년 지역별 인구밀도').add_to(map)    # legend_name : 범례 제목 입력       
cho.geojson.add_child(                                      # 속성 부여
    folium.features.GeoJsonPopup(['CTP_KOR_NM','pop'],labels=False,style='font-weight : bold')
)   # popup 넣기, geo_data의 properties 키의 값들 중 선택 가능, labels : 열이름 유무, style : 서식
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a4d5cfabd1e7f036e5ee4e9f64f5f27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             font-weight : bold
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a4d5cfabd1e7f036e5ee4e9f64f5f27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a4d5cfabd1e7f036e5ee4e9f64f5f27 = L.map(
#                 &quot;map_7a4d5cfabd1e7f036e5ee4e9f64f5f27&quot;,
#                 {
#                     center: [35.230194, 129.074721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b509235f207d68c9b1d95318f50f8b9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7a4d5cfabd1e7f036e5ee4e9f64f5f27);
#
#
#             var choropleth_e986e1514c43fb8e41242a201bc6a942 = L.featureGroup(
#                 {}
#             ).addTo(map_7a4d5cfabd1e7f036e5ee4e9f64f5f27);
#
#
#         function geo_json_6023933fb67e525491a73bed176bec8e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uad11\uc8fc\uad11\uc5ed\uc2dc&quot;: case &quot;\ub300\uad6c\uad11\uc5ed\uc2dc&quot;: case &quot;\ub300\uc804\uad11\uc5ed\uc2dc&quot;: case &quot;\ubd80\uc0b0\uad11\uc5ed\uc2dc&quot;: case &quot;\uc778\ucc9c\uad11\uc5ed\uc2dc&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdd49e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\uc6b8\ud2b9\ubcc4\uc2dc&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6023933fb67e525491a73bed176bec8e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6023933fb67e525491a73bed176bec8e = L.geoJson(null, {
#                 onEachFeature: geo_json_6023933fb67e525491a73bed176bec8e_onEachFeature,
#
#                 style: geo_json_6023933fb67e525491a73bed176bec8e_styler,
#         });
#
#         function geo_json_6023933fb67e525491a73bed176bec8e_add (data) {
#             geo_json_6023933fb67e525491a73bed176bec8e
#                 .addData(data)
#                 .addTo(choropleth_e986e1514c43fb8e41242a201bc6a942);
#         }
#             geo_json_6023933fb67e525491a73bed176bec8e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[128.54880989370014, 38.301950820518755], [128.5600921732829, 38.25735515107489], [128.59761716763322, 38.21480959198724], [128.60765942875406, 38.15215810015938], [128.64206854447866, 38.106588627599855], [128.66939445927846, 38.08634208760778], [128.69458333244307, 38.0453480455091], [128.73326744935343, 38.01787054352603], [128.79463671088126, 37.92801060958252], [128.8233689458956, 37.90753318801803], [128.83001997197184, 37.88458455426084], [128.8786226699225, 37.8294251483049], [128.9852771172376, 37.74045442473868], [129.01482411622038, 37.70600771921262], [129.05505018456222, 37.675224044111836], [129.04353313092116, 37.642745963305245], [129.05392180246835, 37.62123228307141], [129.11550878570839, 37.57855036235084], [129.12163400699842, 37.52066201439543], [129.18932196241568, 37.45204451034289], [129.19776432627512, 37.41521414735909], [129.2513233979134, 37.380088360708676], [129.2506772120506, 37.362368874276115], [129.28084694703435, 37.31347366301054], [129.35527819358379, 37.235059804121235], [129.3411918281742, 37.17718338225454], [129.3633972863588, 37.146000904866405], [129.32482985566594, 37.142286218870495], [129.271238269404, 37.1163805689057], [129.22537770639696, 37.073720111851664], [129.2253141304669, 37.04455999175614], [129.18540948720124, 37.04171908095918], [129.1850295662585, 37.04657953042605], [129.18167891525556, 37.050424880670846], [129.181333033076, 37.05162367047038], [1

# %% [markdown]
# - <span style='color:red'><b>인구 밀도 대비 발전량</b></span>

# %%
#2018년도 지역별 발전량 파일
df = pd.read_csv('data/data_2018.csv',encoding='cp949',index_col=0)
df = df.drop(columns=['거래시간','월','일','년'])
df_18 = df
df_18 = df_18.groupby('지역',as_index=False).sum()
df_18['지역']=df_18['지역'].apply(lambda x : x[:2] if len(x) != 4 else x[0]+x[2])
df_18.rename(columns = {'발전량 ':'발전량'},inplace=True)
df_18 = df_18.sort_values(by='발전량')
df_18 = df_18.sort_values(by=['지역'])
df_18.rename(columns={'발전량':'발전량_2018'},inplace=True)

#2019년도 지역별 발전량 파일
df = pd.read_csv('data/data_2019.csv',encoding='cp949',index_col=0)
df.head(2)
df = df.drop(columns=['거래시간','월','일','년'])
df_19 = df
df_19 = df_19.groupby('지역',as_index=False).sum()
df_19['지역']=df_19['지역'].apply(lambda x : x[:2] if len(x) != 4 else x[0]+x[2])
df_19.rename(columns = {'발전량 ':'발전량'},inplace=True)
df_19 = df_19.sort_values(by='발전량')
df_19 = df_19.sort_values(by=['지역'])
df_19.rename(columns={'발전량':'발전량_2019'},inplace=True)

#2020년도 지역별 발전량 파일
df = pd.read_csv('data/data_2020.csv',encoding='cp949',index_col=0)
df = df.drop(columns=['거래시간','월','일','년'])
df_20 = df
df_20 = df_20.groupby('지역',as_index=False).sum()
df_20['지역']=df_20['지역'].apply(lambda x : x[:2] if len(x) != 4 else x[0]+x[2])
df_20.rename(columns = {'발전량 ':'발전량'},inplace=True)
df_20 = df_20.sort_values(by='발전량')
df_20 = df_20.sort_values(by=['지역'])
df_20.rename(columns={'발전량':'발전량_2020'},inplace=True)

#2021년도 지역별 발전량 파일
df = pd.read_csv('data/data_2021.csv',encoding='cp949',index_col=0)
df = df.drop(columns=['거래시간','월','일','년'])
df_21 = df
df_21 = df_21.groupby('지역',as_index=False).sum()
df_21['지역']=df_21['지역'].apply(lambda x : x[:2] if len(x) != 4 else x[0]+x[2])
df_21.rename(columns = {'발전량 ':'발전량'},inplace=True)
df_21 = df_21.sort_values(by='발전량')
df_21 = df_21.sort_values(by=['지역'])
df_21.rename(columns={'발전량':'발전량_2021'},inplace=True)

# %%
df = pd.read_csv('data/년도별_인구밀도.csv',encoding='cp949',index_col=0)
df.rename(columns={'2018':'인구밀도_2018','2019':'인구밀도_2019','2020':'인구밀도_2020','2021':'인구밀도_2021'},inplace=True)
df.head(2)
# Out:
#    지역  인구밀도_2018  인구밀도_2019  인구밀도_2020  인구밀도_2021
# 9  강원       90.3       90.3       90.4       90.4
# 8  경기     1286.2     1305.0     1325.3     1338.9

# %%
m_df = pd.merge(df_18,df_19)
m_df = pd.merge(m_df,df_20)
m_df = pd.merge(m_df,df_21)
mer_df = pd.merge(m_df,df)
mer_df.head(2)
# Out:
#    지역      발전량_2018      발전량_2019      발전량_2020      발전량_2021  인구밀도_2018  \
# 0  강원  2.412912e+08  3.161680e+08  4.110145e+08  5.617457e+08       90.3
# 1  경기  1.476772e+08  1.783767e+08  2.332467e+08  3.062760e+08     1286.2
#
#    인구밀도_2019  인구밀도_2020  인구밀도_2021
# 0       90.3       90.4       90.4
# 1     1305.0     1325.3     1338.9

# %%
# mer_df.to_csv('data/인구밀도_태양광전력량.csv',encoding='cp949')
# mer_df.head(2)

# %%
#년도별로 지역, 인구밀도와 발전량
m_18 = mer_df[['지역','발전량_2018','인구밀도_2018']]
m_18 = m_18.set_index('지역')

m_19 = mer_df[['지역','발전량_2019','인구밀도_2019']]
m_19 = m_19.set_index('지역')

m_20 = mer_df[['지역','발전량_2020','인구밀도_2020']]
m_20 = m_20.set_index('지역')

m_21 = mer_df[['지역','발전량_2021','인구밀도_2021']]
m_21 = m_21.set_index('지역')
m_21.head(2)
# Out:
#         발전량_2021  인구밀도_2021
# 지역
# 강원  5.617457e+08       90.4
# 경기  3.062760e+08     1338.9

# %%
#18년도
fig, ax1 = plt.subplots(figsize=(16,6),nrows=2,ncols=2)
color_1 = 'tab:blue'
ax1[0,0].set_title('인구밀도 대비_지역별_2018', fontsize=13)
ax1[0,0].set_xlabel('지역')
ax1[0,0].set_ylabel('태양광발전량', fontsize=14, color=color_1)
ax1[0,0].plot(m_18.index, m_18.발전량_2018, marker='o', color=color_1,linewidth=3)
ax1[0,0].tick_params(axis='y', labelcolor=color_1)

ax2 = ax1[0,0].twinx() 
color_2 = 'tab:green'
ax2.set_ylabel('인구밀도', fontsize=14, color=color_2)
ax2.plot(m_18.index, m_18.인구밀도_2018, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


#19년도
color_1 = 'tab:blue'
ax1[0,1].set_title('인구밀도 대비_지역별_2019', fontsize=13)
ax1[0,1].set_xlabel('지역')
ax1[0,1].set_ylabel('태양광발전량', fontsize=14, color=color_1)
ax1[0,1].plot(m_19.index, m_19.발전량_2019, marker='o', color=color_1,linewidth=3)
ax1[0,1].tick_params(axis='y', labelcolor=color_1)

ax2 = ax1[0,1].twinx() 
color_2 = 'tab:green'
ax2.set_ylabel('인구밀도', fontsize=14, color=color_2)
ax2.plot(m_19.index, m_19.인구밀도_2019, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


#20년도
color_1 = 'tab:blue'
ax1[1,0].set_title('인구밀도 대비_지역별_2020', fontsize=13)
ax1[1,0].set_xlabel('지역')
ax1[1,0].set_ylabel('태양광발전량', fontsize=14, color=color_1)
ax1[1,0].plot(m_20.index, m_20.발전량_2020, marker='o', color=color_1,linewidth=3)
ax1[1,0].tick_params(axis='y', labelcolor=color_1)

ax2 = ax1[1,0].twinx() 
color_2 = 'tab:green'
ax2.set_ylabel('인구밀도', fontsize=14, color=color_2)
ax2.plot(m_20.index, m_20.인구밀도_2020, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


#21년도
color_1 = 'tab:blue'
ax1[1,1].set_title('인구밀도 대비_지역별_2021', fontsize=13)
ax1[1,1].set_xlabel('지역')
ax1[1,1].set_ylabel('태양광발전량', fontsize=14, color=color_1)
ax1[1,1].plot(m_21.index, m_21.발전량_2021, marker='o', color=color_1,linewidth=3)
ax1[1,1].tick_params(axis='y', labelcolor=color_1)

ax2 = ax1[1,1].twinx() 
color_2 = 'tab:green'
ax2.set_ylabel('인구밀도', fontsize=14, color=color_2)
ax2.plot(m_21.index, m_21.인구밀도_2021, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

fig.tight_layout()
plt.show()

# %% [markdown]
# - <span style='color:red'><b>연도별 목포 태양광발전량

# %%
data=pd.read_csv('data3/목포data.csv',encoding='cp949')
data.hist(figsize=(10,9))
plt.tight_layout()
plt.show()

# %%
data=data[['일시', '기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '습도(%)',
       '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '일조(hr)',
       '일사(MJ/m2)', '적설(cm)', '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)',
       '운형(운형약어)', '최저운고(100m )', '시정(10m)', '지면상태(지면상태코드)', '현상번호(국내식)',
       '지면온도(°C)', '5cm 지중온도(°C)', '10cm 지중온도(°C)', '20cm 지중온도(°C)',
       '30cm 지중온도(°C)']]
data=data.rename(columns={'일시':'date'})
data['Time'] = pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M', errors='raise')
data['Year'] = data['Time'].dt.year
data['Month'] = data['Time'].dt.month
data['Day'] = data['Time'].dt.day
data['Hour'] = data['Time'].dt.hour
data=data[['Year','Month','Day','Hour','기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '습도(%)',
       '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '일조(hr)',
       '일사(MJ/m2)', '적설(cm)', '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)',
       '운형(운형약어)', '최저운고(100m )', '시정(10m)', '지면상태(지면상태코드)', '현상번호(국내식)',
       '지면온도(°C)', '5cm 지중온도(°C)', '10cm 지중온도(°C)', '20cm 지중온도(°C)',
       '30cm 지중온도(°C)']]
data.hist(figsize=(10,9))
plt.tight_layout()
plt.show()

# %%
from datetime import timedelta

test = pd.read_csv('data3/태양광_지역별시간별발전량_2021.csv',encoding='cp949')
test['거래일자'] = pd.to_datetime(test['거래일자']) 
def up_date(x):
    if x[1] == 24:
        return x[0]+timedelta(days=1)
    else:
        return x[0]+timedelta(hours=x[1])
test['일시'] = test[['거래일자','거래시간']].apply(up_date,axis=1)
test=test[['일시','지역','발전량 ']]
test=test.drop(596087)
test=test[test['지역']=='전라남도']
test_1 = pd.DataFrame({'일시' : ['2018-01-01 00:00:00'],'지역' : ['전라남도'],'발전량 ' : 0.000})
test= pd.concat([test_1,test],axis=0)
test=test.drop(595991)
test=test.rename(columns={'일시':'date','발전량 ':'generation'})
test['Time'] = pd.to_datetime(test['date'], format='%Y-%m-%d %H:%M', errors='raise')
test['Year'] = test['Time'].dt.year
test['Month'] = test['Time'].dt.month
test['Day'] = test['Time'].dt.day
test['Hour'] = test['Time'].dt.hour 
test=test[['Year','Month','Day','Hour','generation']]
test.reset_index(drop=True,inplace=True)

# %%
df=pd.merge(test,data,how='left',on=['Year','Month','Day','Hour'])
df=df.fillna(0)
df1=df.groupby(['Year','Month'])['generation'].mean().reset_index()
df1['Year']=df1['Year'].astype(int)
df1['Month']=df1['Month'].astype(int)
df1['generation']=df1['generation'].astype(int)
df1_18=df1[df1['Year']==2018].reset_index(drop=True)
df1_19=df1[df1['Year']==2019].reset_index(drop=True)
df1_20=df1[df1['Year']==2020].reset_index(drop=True)
df1_21=df1[df1['Year']==2021].reset_index(drop=True)

# %%
plt.plot(df1_18['Month'],df1_18['generation'])
plt.plot(df1_19['Month'],df1_19['generation']) 
plt.plot(df1_20['Month'],df1_20['generation']) 
plt.plot(df1_21['Month'],df1_21['generation']) 
plt.title('연도별 발전량')
plt.show()

# %%
df1_18=df1_18[['Month','generation']]
df1_18=df1_18.set_index('Month')
df1_18=df1_18.rename(columns={'generation':'발전량_18'})
df1_19=df1_19[['Month','generation']]
df1_19=df1_19.set_index('Month')
df1_19=df1_19.rename(columns={'generation':'발전량_19'})
df1_20=df1_20[['Month','generation']]
df1_20=df1_20.set_index('Month')
df1_20=df1_20.rename(columns={'generation':'발전량_20'})
df1_21=df1_21[['Month','generation']]
df1_21=df1_21.set_index('Month')
df1_21=df1_21.rename(columns={'generation':'발전량_21'})
df=pd.concat([df1_18,df1_19,df1_20,df1_21],axis=1)

# %%
df.plot(kind='bar')
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# - <span style='color:red'><b>기상데이터 대비 발전량(평균기온/평균운량/일조율/일사량/평균상대습도/월합강수량/평균풍속)

# %%
prod_data = pd.read_csv('data3/태양광_지역별시간별발전량_2021.csv',encoding='cp949')
jeonnam = prod_data[prod_data['지역']=='전라남도']
jeonnam.set_index(jeonnam['지역'],inplace=True)
jeonnam.drop(columns='지역',inplace=True)
jeonnam.index.name =''
jeonnam = jeonnam[(jeonnam['거래시간'] > 8) & (jeonnam['거래시간'] < 19)]
loc = '목포' 
mokpo = []
for i in range(18,22):
    mp = pd.read_csv('data3'+'/'+'시간_' + loc +str(i)+'.csv',encoding='cp949')
    mokpo.append(mp)
for id, k in enumerate(mokpo):
    k['시'] = k['일시'].apply(lambda x : int(x.split()[1].split(':')[0]))
    k['일시'] = k['일시'].apply(lambda x : x.split()[0])
    adv = k[(k['시'] > 8) & (k['시'] < 19)]
    mokpo[id] = adv
mokpo = pd.concat(mokpo)
mokpo.rename(columns = {'시':'거래시간','일시' : '거래일자'},inplace=True)
mokpo.head()
m_data = pd.merge(jeonnam, mokpo, how='inner',on=['거래일자','거래시간'])
mjeonnam = pd.read_csv('data3/태양광_지역별시간별발전량_2021.csv',encoding='cp949')
mjeonnam = prod_data[prod_data['지역']=='전라남도']
mjeonnam.set_index(mjeonnam['지역'],inplace=True)
mjeonnam.drop(columns='지역',inplace=True)
mjeonnam.index.name =''
mjeonnam['거래일자'] = mjeonnam['거래일자'].apply(lambda x : x.split('-')[0] + x.split('-')[1])
monthly = mjeonnam.groupby('거래일자')['발전량 '].sum().to_frame()
monthly.index.name =''
monthly.reset_index(inplace=True)
monthly.columns = ['일시','발전량']
loc = '목포'
dist = []
for i in range(18,22):
    mp = pd.read_csv('data3'+'/'+'월_' + loc +str(i)+'.csv',encoding='cp949')
    dist.append(mp)
for id, k in enumerate(dist):
    k['일시'] = k['일시'].apply(lambda x : ''.join(x.split('-')))
    k.index = list(range(12))
dist[0].columns = dist[1].columns
dist = pd.concat(dist)
monthly_data = pd.merge(monthly, dist, how='inner',on='일시')

# %%
data=monthly_data[['일시','발전량','평균기온(°C)','평균운량(1/10)','일조율(%)','합계 일사량(MJ/m2)']]
data['연도']=data['일시'].str[0:4]
data['월']=data['일시'].str[4:6]
data_temp=data[['연도','월','발전량','평균기온(°C)']]
data_18_temp=data_temp[data_temp['연도']=='2018']
data_18_temp=data_18_temp.rename(columns={'평균기온(°C)':'평균기온'})
data_18_temp=data_18_temp.drop(columns='연도')
data_18_temp=data_18_temp.set_index('월')
data_19_temp=data_temp[data_temp['연도']=='2019']
data_19_temp=data_19_temp.rename(columns={'평균기온(°C)':'평균기온'})
data_19_temp=data_19_temp.drop(columns='연도')
data_19_temp=data_19_temp.set_index('월')
data_20_temp=data_temp[data_temp['연도']=='2020']
data_20_temp=data_20_temp.rename(columns={'평균기온(°C)':'평균기온'})
data_20_temp=data_20_temp.drop(columns='연도')
data_20_temp=data_20_temp.set_index('월')
data_21_temp=data_temp[data_temp['연도']=='2021']
data_21_temp=data_21_temp.rename(columns={'평균기온(°C)':'평균기온'})
data_21_temp=data_21_temp.drop(columns='연도')
data_21_temp=data_21_temp.set_index('월')
data_cc=data[['연도','월','발전량','평균운량(1/10)']] # 운량 영어로 cloud cover
data_cc=data_cc.rename(columns={'평균운량(1/10)':'평균운량'})
data_18_cc=data_cc[data_cc['연도']=='2018']
data_18_cc=data_18_cc.drop(columns='연도')
data_18_cc=data_18_cc.set_index('월')
data_19_cc=data_cc[data_cc['연도']=='2019']
data_19_cc=data_19_cc.drop(columns='연도')
data_19_cc=data_19_cc.set_index('월')
data_20_cc=data_cc[data_cc['연도']=='2020']
data_20_cc=data_20_cc.drop(columns='연도')
data_20_cc=data_20_cc.set_index('월')
data_21_cc=data_cc[data_cc['연도']=='2021']
data_21_cc=data_21_cc.drop(columns='연도')
data_21_cc=data_21_cc.set_index('월')
data_rs=data[['연도','월','발전량','일조율(%)']] # 일조율:rate of sunshine
data_rs=data_rs.rename(columns={'일조율(%)':'일조율'})
data_18_rs=data_rs[data_rs['연도']=='2018']
data_18_rs=data_18_rs.drop(columns='연도')
data_18_rs=data_18_rs.set_index('월')
data_19_rs=data_rs[data_rs['연도']=='2019']
data_19_rs=data_19_rs.drop(columns='연도')
data_19_rs=data_19_rs.set_index('월')
data_20_rs=data_rs[data_rs['연도']=='2020']
data_20_rs=data_20_rs.drop(columns='연도')
data_20_rs=data_20_rs.set_index('월')
data_21_rs=data_rs[data_rs['연도']=='2021']
data_21_rs=data_21_rs.drop(columns='연도')
data_21_rs=data_21_rs.set_index('월')
data_sr=data[['연도','월','발전량','합계 일사량(MJ/m2)']] # 일사량:solar radiation
data_sr=data_sr.rename(columns={'합계 일사량(MJ/m2)':'합계일사량'})
data_18_sr=data_sr[data_sr['연도']=='2018']
data_18_sr=data_18_sr.drop(columns='연도')
data_18_sr=data_18_sr.set_index('월')
data_19_sr=data_sr[data_sr['연도']=='2019']
data_19_sr=data_19_sr.drop(columns='연도')
data_19_sr=data_19_sr.set_index('월')
data_20_sr=data_sr[data_sr['연도']=='2020']
data_20_sr=data_20_sr.drop(columns='연도')
data_20_sr=data_20_sr.set_index('월')
data_21_sr=data_sr[data_sr['연도']=='2021']
data_21_sr=data_21_sr.drop(columns='연도')
data_21_sr=data_21_sr.set_index('월')
fig, ax1 = plt.subplots(figsize=(20,10),nrows=4,ncols=4)

# 1행 1열 - 2018 기온별 발전량
color_1 = 'tab:gray'
ax1[0,0].set_title('목포 평균기온별 발전량_2018', fontsize=12)
ax1[0,0].set_xlabel('월')
ax1[0,0].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[0,0].plot(data_18_temp.index, data_18_temp.발전량, marker='o', color=color_1,linewidth=3)
ax1[0,0].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[0,0].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:orange'
ax2.set_ylabel('평균 기온', fontsize=12, color=color_2)
ax2.plot(data_18_temp.index, data_18_temp.평균기온, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 1행 2열 - 2018 운량별 발전량
color_1 = 'tab:gray'
ax1[0,1].set_title('목포 평균운량별 발전량_2018', fontsize=12)
ax1[0,1].set_xlabel('월')
ax1[0,1].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[0,1].plot(data_18_cc.index, data_18_cc.발전량, marker='o', color=color_1,linewidth=3)
ax1[0,1].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[0,1].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:blue'
ax2.set_ylabel('평균 운량', fontsize=12, color=color_2)
ax2.plot(data_18_cc.index, data_18_cc.평균운량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


# 1행 3열 - 2018 일조율별 발전량
color_1 = 'tab:gray'
ax1[0,2].set_title('목포 일조율별 발전량_2018', fontsize=12)
ax1[0,2].set_xlabel('월')
ax1[0,2].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[0,2].plot(data_18_rs.index, data_18_rs.발전량, marker='o', color=color_1,linewidth=3)
ax1[0,2].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[0,2].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:pink'
ax2.set_ylabel('일조율', fontsize=12, color=color_2)
ax2.plot(data_18_rs.index, data_18_rs.일조율, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


# 1행 4열 - 2018 합계 일사량별 발전량
color_1 = 'tab:gray'
ax1[0,3].set_title('목포 합계 일사량별 발전량_2018', fontsize=12)
ax1[0,3].set_xlabel('월')
ax1[0,3].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[0,3].plot(data_18_sr.index, data_18_sr.발전량, marker='o', color=color_1,linewidth=3)
ax1[0,3].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[0,3].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('합계일사량', fontsize=12, color=color_2)
ax2.plot(data_18_sr.index, data_18_sr.합계일사량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


# 2행 1열 - 2019 기온별 발전량
color_1 = 'tab:gray'
ax1[1,0].set_title('목포 평균기온별 발전량_2019', fontsize=12)
ax1[1,0].set_xlabel('월')
ax1[1,0].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[1,0].plot(data_19_temp.index, data_19_temp.발전량, marker='o', color=color_1,linewidth=3)
ax1[1,0].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[1,0].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:orange'
ax2.set_ylabel('평균 기온', fontsize=12, color=color_2)
ax2.plot(data_19_temp.index, data_19_temp.평균기온, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 2행 2열 - 2019 운량별 발전량
color_1 = 'tab:gray'
ax1[1,1].set_title('목포 평균운량별 발전량_2019', fontsize=12)
ax1[1,1].set_xlabel('월')
ax1[1,1].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[1,1].plot(data_19_cc.index, data_19_cc.발전량, marker='o', color=color_1,linewidth=3)
ax1[1,1].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[1,1].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:blue'
ax2.set_ylabel('평균 운량', fontsize=12, color=color_2)
ax2.plot(data_19_cc.index, data_19_cc.평균운량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 2행 3열 - 2019 일조율별 발전량
color_1 = 'tab:gray'
ax1[1,2].set_title('목포 일조율별 발전량_2019', fontsize=12)
ax1[1,2].set_xlabel('월')
ax1[1,2].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[1,2].plot(data_19_rs.index, data_19_rs.발전량, marker='o', color=color_1,linewidth=3)
ax1[1,2].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[1,2].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:pink'
ax2.set_ylabel('일조율', fontsize=12, color=color_2)
ax2.plot(data_19_rs.index, data_19_rs.일조율, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 2행 4열 - 2019 합계 일사량별 발전량
color_1 = 'tab:gray'
ax1[1,3].set_title('목포 합계 일사량별 발전량_2019', fontsize=12)
ax1[1,3].set_xlabel('월')
ax1[1,3].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[1,3].plot(data_19_sr.index, data_19_sr.발전량, marker='o', color=color_1,linewidth=3)
ax1[1,3].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[1,3].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('합계일사량', fontsize=12, color=color_2)
ax2.plot(data_19_sr.index, data_19_sr.합계일사량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 3행 1열 - 2020 기온별 발전량
color_1 = 'tab:gray'
ax1[2,0].set_title('목포 평균기온별 발전량_2020', fontsize=12)
ax1[2,0].set_xlabel('월')
ax1[2,0].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[2,0].plot(data_20_temp.index, data_20_temp.발전량, marker='o', color=color_1,linewidth=3)
ax1[2,0].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[2,0].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:orange'
ax2.set_ylabel('평균 기온', fontsize=12, color=color_2)
ax2.plot(data_20_temp.index, data_20_temp.평균기온, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 3행 2열 - 2020 운량별 발전량
color_1 = 'tab:gray'
ax1[2,1].set_title('목포 평균운량별 발전량_2020', fontsize=12)
ax1[2,1].set_xlabel('월')
ax1[2,1].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[2,1].plot(data_20_cc.index, data_20_cc.발전량, marker='o', color=color_1,linewidth=3)
ax1[2,1].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[2,1].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:blue'
ax2.set_ylabel('평균 운량', fontsize=12, color=color_2)
ax2.plot(data_20_cc.index, data_20_cc.평균운량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 3행 3열 - 2020 일조율별 발전량
color_1 = 'tab:gray'
ax1[2,2].set_title('목포 일조율별 발전량_2020', fontsize=12)
ax1[2,2].set_xlabel('월')
ax1[2,2].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[2,2].plot(data_18_cc.index, data_18_cc.발전량, marker='o', color=color_1,linewidth=3)
ax1[2,2].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[2,2].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:pink'
ax2.set_ylabel('일조율', fontsize=12, color=color_2)
ax2.plot(data_20_rs.index, data_20_rs.일조율, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 3행 4열 - 2020 합계 일사량별 발전량
color_1 = 'tab:gray'
ax1[2,3].set_title('목포 합계 일사량별 발전량_2020', fontsize=12)
ax1[2,3].set_xlabel('월')
ax1[2,3].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[2,3].plot(data_20_sr.index, data_20_sr.발전량, marker='o', color=color_1,linewidth=3)
ax1[2,3].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[2,3].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('합계일사량', fontsize=12, color=color_2)
ax2.plot(data_20_sr.index, data_20_sr.합계일사량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 4행 1열 - 2021 기온별 발전량
color_1 = 'tab:gray'
ax1[3,0].set_title('목포 평균기온별 발전량_2021', fontsize=12)
ax1[3,0].set_xlabel('월')
ax1[3,0].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[3,0].plot(data_21_temp.index, data_21_temp.발전량, marker='o', color=color_1,linewidth=3)
ax1[3,0].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[3,0].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:orange'
ax2.set_ylabel('평균 기온', fontsize=12, color=color_2)
ax2.plot(data_21_temp.index, data_21_temp.평균기온, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 4행 2열 - 2021 운량별 발전량
color_1 = 'tab:gray'
ax1[3,1].set_title('목포 평균운량별 발전량_2018', fontsize=12)
ax1[3,1].set_xlabel('월')
ax1[3,1].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[3,1].plot(data_21_cc.index, data_21_cc.발전량, marker='o', color=color_1,linewidth=3)
ax1[3,1].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[3,1].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:blue'
ax2.set_ylabel('평균 운량', fontsize=12, color=color_2)
ax2.plot(data_21_cc.index, data_21_cc.평균운량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 4행 3열 - 2021 일조율별 발전량
color_1 = 'tab:gray'
ax1[3,2].set_title('목포 일조율별 발전량_2021', fontsize=12)
ax1[3,2].set_xlabel('월')
ax1[3,2].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[3,2].plot(data_21_rs.index, data_21_rs.발전량, marker='o', color=color_1,linewidth=3)
ax1[3,2].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[3,2].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:pink'
ax2.set_ylabel('일조율', fontsize=12, color=color_2)
ax2.plot(data_21_rs.index, data_21_rs.일조율, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 4행 4열 - 2021 합계 일사량별 발전량
color_1 = 'tab:gray'
ax1[3,3].set_title('목포 합계 일사량별 발전량_2021', fontsize=12)
ax1[3,3].set_xlabel('월')
ax1[3,3].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[3,3].plot(data_21_sr.index, data_21_sr.발전량, marker='o', color=color_1,linewidth=3)
ax1[3,3].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[3,3].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('합계일사량', fontsize=12, color=color_2)
ax2.plot(data_21_sr.index, data_21_sr.합계일사량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

fig.tight_layout()
plt.show()

# %%
data1=monthly_data[['일시','발전량','평균상대습도(%)','월합강수량(00~24h만)(mm)','평균풍속(m/s)']]
data1['연도']=data1['일시'].str[0:4]
data1['월']=data1['일시'].str[4:6]
data_hu=data1[['연도','월','발전량','평균상대습도(%)']] 
data_hu=data_hu.rename(columns={'평균상대습도(%)':'평균상대습도'})
data_18_hu=data_hu[data_hu['연도']=='2018']
data_18_hu=data_18_hu.drop(columns='연도')
data_18_hu=data_18_hu.set_index('월')
data_19_hu=data_hu[data_hu['연도']=='2019']
data_19_hu=data_19_hu.drop(columns='연도')
data_19_hu=data_19_hu.set_index('월')
data_20_hu=data_hu[data_hu['연도']=='2020']
data_20_hu=data_20_hu.drop(columns='연도')
data_20_hu=data_20_hu.set_index('월')
data_21_hu=data_hu[data_hu['연도']=='2021']
data_21_hu=data_21_hu.drop(columns='연도')
data_21_hu=data_21_hu.set_index('월')
data_ra=data1[['연도','월','발전량','월합강수량(00~24h만)(mm)']] 
data_ra=data_ra.rename(columns={'월합강수량(00~24h만)(mm)':'월합강수량'})
data_18_ra=data_ra[data_ra['연도']=='2018']
data_18_ra=data_18_ra.drop(columns='연도')
data_18_ra=data_18_ra.set_index('월')
data_19_ra=data_ra[data_ra['연도']=='2019']
data_19_ra=data_19_ra.drop(columns='연도')
data_19_ra=data_19_ra.set_index('월')
data_20_ra=data_ra[data_ra['연도']=='2020']
data_20_ra=data_20_ra.drop(columns='연도')
data_20_ra=data_20_ra.set_index('월')
data_21_ra=data_ra[data_ra['연도']=='2021']
data_21_ra=data_21_ra.drop(columns='연도')
data_21_ra=data_21_ra.set_index('월')
data_wi=data1[['연도','월','발전량','평균풍속(m/s)']] 
data_wi=data_wi.rename(columns={'평균풍속(m/s)':'평균풍속'})
data_18_wi=data_wi[data_wi['연도']=='2018']
data_18_wi=data_18_wi.drop(columns='연도')
data_18_wi=data_18_wi.set_index('월')
data_19_wi=data_wi[data_wi['연도']=='2019']
data_19_wi=data_19_wi.drop(columns='연도')
data_19_wi=data_19_wi.set_index('월')
data_20_wi=data_wi[data_wi['연도']=='2020']
data_20_wi=data_20_wi.drop(columns='연도')
data_20_wi=data_20_wi.set_index('월')
data_21_wi=data_wi[data_wi['연도']=='2021']
data_21_wi=data_21_wi.drop(columns='연도')
data_21_wi=data_21_wi.set_index('월')
fig, ax1 = plt.subplots(figsize=(20,10),nrows=4,ncols=4)

# 1행 1열 - 2018 평균상대습도별 발전량
color_1 = 'tab:gray'
ax1[0,0].set_title('목포 평균상대습도별 발전량_2018', fontsize=12)
ax1[0,0].set_xlabel('월')
ax1[0,0].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[0,0].plot(data_18_hu.index, data_18_hu.발전량, marker='o', color=color_1,linewidth=3)
ax1[0,0].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[0,0].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:green'
ax2.set_ylabel('평균상대습도', fontsize=12, color=color_2)
ax2.plot(data_18_hu.index, data_18_hu.평균상대습도, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 1행 2열 - 2018 월합강수량별 발전량
color_1 = 'tab:gray'
ax1[0,1].set_title('목포 월합강수량별 발전량_2018', fontsize=12)
ax1[0,1].set_xlabel('월')
ax1[0,1].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[0,1].plot(data_18_ra.index, data_18_ra.발전량, marker='o', color=color_1,linewidth=3)
ax1[0,1].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[0,1].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:purple'
ax2.set_ylabel('월합강수량', fontsize=12, color=color_2)
ax2.plot(data_18_ra.index, data_18_ra.월합강수량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


# 1행 3열 - 2018 평균풍속별 발전량
color_1 = 'tab:gray'
ax1[0,2].set_title('목포 평균풍속별 발전량_2018', fontsize=12)
ax1[0,2].set_xlabel('월')
ax1[0,2].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[0,2].plot(data_18_wi.index, data_18_wi.발전량, marker='o', color=color_1,linewidth=3)
ax1[0,2].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[0,2].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:olive'
ax2.set_ylabel('평균풍속', fontsize=12, color=color_2)
ax2.plot(data_18_wi.index, data_18_wi.평균풍속, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


# 1행 4열 - 2018 합계 일사량별 발전량
color_1 = 'tab:gray'
ax1[0,3].set_title('목포 합계 일사량별 발전량_2018', fontsize=12)
ax1[0,3].set_xlabel('월')
ax1[0,3].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[0,3].plot(data_18_sr.index, data_18_sr.발전량, marker='o', color=color_1,linewidth=3)
ax1[0,3].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[0,3].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('합계일사량', fontsize=12, color=color_2)
ax2.plot(data_18_sr.index, data_18_sr.합계일사량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)


# 2행 1열 - 2019 평균상대습도별 발전량
color_1 = 'tab:gray'
ax1[1,0].set_title('목포 평균상대습도별 발전량_2019', fontsize=12)
ax1[1,0].set_xlabel('월')
ax1[1,0].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[1,0].plot(data_19_hu.index, data_19_hu.발전량, marker='o', color=color_1,linewidth=3)
ax1[1,0].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[1,0].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:green'
ax2.set_ylabel('평균상대습도', fontsize=12, color=color_2)
ax2.plot(data_19_hu.index, data_19_hu.평균상대습도, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 2행 2열 - 2019 월합강수량별 발전량
color_1 = 'tab:gray'
ax1[1,1].set_title('목포 월합강수량별 발전량_2019', fontsize=12)
ax1[1,1].set_xlabel('월')
ax1[1,1].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[1,1].plot(data_19_ra.index, data_19_ra.발전량, marker='o', color=color_1,linewidth=3)
ax1[1,1].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[1,1].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:purple'
ax2.set_ylabel('월합강수량', fontsize=12, color=color_2)
ax2.plot(data_19_ra.index, data_19_ra.월합강수량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 2행 3열 - 2019 평균풍속별 발전량
color_1 = 'tab:gray'
ax1[1,2].set_title('목포 평균풍속별 발전량_2019', fontsize=12)
ax1[1,2].set_xlabel('월')
ax1[1,2].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[1,2].plot(data_19_wi.index, data_19_wi.발전량, marker='o', color=color_1,linewidth=3)
ax1[1,2].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[1,2].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:olive'
ax2.set_ylabel('평균풍속별', fontsize=12, color=color_2)
ax2.plot(data_19_wi.index, data_19_wi.평균풍속, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 2행 4열 - 2019 합계 일사량별 발전량
color_1 = 'tab:gray'
ax1[1,3].set_title('목포 합계 일사량별 발전량_2019', fontsize=12)
ax1[1,3].set_xlabel('월')
ax1[1,3].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[1,3].plot(data_19_sr.index, data_19_sr.발전량, marker='o', color=color_1,linewidth=3)
ax1[1,3].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[1,3].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('합계일사량', fontsize=12, color=color_2)
ax2.plot(data_19_sr.index, data_19_sr.합계일사량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 3행 1열 - 2020 평균상대습도별 발전량
color_1 = 'tab:gray'
ax1[2,0].set_title('목포 평균상대습도별 발전량_2020', fontsize=12)
ax1[2,0].set_xlabel('월')
ax1[2,0].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[2,0].plot(data_20_hu.index, data_20_hu.발전량, marker='o', color=color_1,linewidth=3)
ax1[2,0].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[2,0].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:green'
ax2.set_ylabel('평균상대습도', fontsize=12, color=color_2)
ax2.plot(data_20_hu.index, data_20_hu.평균상대습도, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 3행 2열 - 2020 월합강수량별 발전량
color_1 = 'tab:gray'
ax1[2,1].set_title('목포 월합강수량별 발전량_2020', fontsize=12)
ax1[2,1].set_xlabel('월')
ax1[2,1].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[2,1].plot(data_20_ra.index, data_20_ra.발전량, marker='o', color=color_1,linewidth=3)
ax1[2,1].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[2,1].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:purple'
ax2.set_ylabel('월합강수량', fontsize=12, color=color_2)
ax2.plot(data_20_ra.index, data_20_ra.월합강수량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 3행 3열 - 2020 평균풍속별 발전량
color_1 = 'tab:gray'
ax1[2,2].set_title('목포 평균풍속별 발전량_2020', fontsize=12)
ax1[2,2].set_xlabel('월')
ax1[2,2].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[2,2].plot(data_18_wi.index, data_18_wi.발전량, marker='o', color=color_1,linewidth=3)
ax1[2,2].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[2,2].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:olive'
ax2.set_ylabel('평균풍속', fontsize=12, color=color_2)
ax2.plot(data_20_wi.index, data_20_wi.평균풍속, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 3행 4열 - 2020 합계 일사량별 발전량
color_1 = 'tab:gray'
ax1[2,3].set_title('목포 합계 일사량별 발전량_2020', fontsize=12)
ax1[2,3].set_xlabel('월')
ax1[2,3].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[2,3].plot(data_20_sr.index, data_20_sr.발전량, marker='o', color=color_1,linewidth=3)
ax1[2,3].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[2,3].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('합계일사량', fontsize=12, color=color_2)
ax2.plot(data_20_sr.index, data_20_sr.합계일사량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 4행 1열 - 2021 평균상대습도별 발전량
color_1 = 'tab:gray'
ax1[3,0].set_title('목포 평균상대습도별 발전량_2021', fontsize=12)
ax1[3,0].set_xlabel('월')
ax1[3,0].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[3,0].plot(data_21_hu.index, data_21_hu.발전량, marker='o', color=color_1,linewidth=3)
ax1[3,0].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[3,0].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:green'
ax2.set_ylabel('평균상대습도', fontsize=12, color=color_2)
ax2.plot(data_21_hu.index, data_21_hu.평균상대습도, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 4행 2열 - 2021 월합강수량별 발전량
color_1 = 'tab:gray'
ax1[3,1].set_title('목포 월합강수량별 발전량_2021', fontsize=12)
ax1[3,1].set_xlabel('월')
ax1[3,1].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[3,1].plot(data_21_ra.index, data_21_ra.발전량, marker='o', color=color_1,linewidth=3)
ax1[3,1].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[3,1].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:purple'
ax2.set_ylabel('월합강수량', fontsize=12, color=color_2)
ax2.plot(data_21_ra.index, data_21_ra.월합강수량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 4행 3열 - 2021 평균풍속별 발전량
color_1 = 'tab:gray'
ax1[3,2].set_title('목포 평균풍속별 발전량_2021', fontsize=12)
ax1[3,2].set_xlabel('월')
ax1[3,2].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[3,2].plot(data_21_wi.index, data_21_wi.발전량, marker='o', color=color_1,linewidth=3)
ax1[3,2].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[3,2].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:olive'
ax2.set_ylabel('평균풍속', fontsize=12, color=color_2)
ax2.plot(data_21_wi.index, data_21_wi.평균풍속, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

# 4행 4열 - 2021 합계 일사량별 발전량
color_1 = 'tab:gray'
ax1[3,3].set_title('목포 합계 일사량별 발전량_2021', fontsize=12)
ax1[3,3].set_xlabel('월')
ax1[3,3].set_ylabel('발전량', fontsize=12, color=color_1)
ax1[3,3].plot(data_21_sr.index, data_21_sr.발전량, marker='o', color=color_1,linewidth=3)
ax1[3,3].tick_params(axis='y', labelcolor=color_1)

# right side with different scale
ax2 = ax1[3,3].twinx() # instantiate a second axes that shares the same x-axis
color_2 = 'tab:red'
ax2.set_ylabel('합계일사량', fontsize=12, color=color_2)
ax2.plot(data_21_sr.index, data_21_sr.합계일사량, marker='o', color=color_2,linewidth=3)
ax2.tick_params(axis='y', labelcolor=color_2)

fig.tight_layout()
plt.show()
